# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_train=pd.read_csv('/content/drive/MyDrive/GreatLearning/Airline/train.csv')
df_test=pd.read_csv('/content/drive/MyDrive/GreatLearning/Airline/test.csv')

# %%
df=pd.concat([df_train,df_test])

# %%
df.head()
# Out:
#    Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 0           0   70172  ...                     18.0  neutral or dissatisfied
# 1           1    5047  ...                      6.0  neutral or dissatisfied
# 2           2  110028  ...                      0.0                satisfied
# 3           3   24026  ...                      9.0  neutral or dissatisfied
# 4           4  119299  ...                      0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df['Flight Distance'].min(),df['Flight Distance'].max()
# Out:
# (31, 4983)

# %%
df['Flight_Distance'] = pd.cut(x=df['Flight Distance'], bins=[0, 1660,3320,5000],
                    labels=[0,1,2])

# %%
df['Flight_Distance'].value_counts()
# Out:
# 0    95338
# 1    27444
# 2     7098
# Name: Flight_Distance, dtype: int64

# %%
df.drop(['Unnamed: 0','id'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129880 entries, 0 to 25975
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# ...

# %%
df['Arrival Delay in Minutes']
# Out:
# 0        18.0
# 1         6.0
# 2         0.0
# 3         9.0
# 4         0.0
#          ...
# 25971     0.0
# 25972     0.0
# 25973     0.0
# 25974     0.0
# 25975     0.0
# Name: Arrival Delay in Minutes, Length: 129880, dtype: float64

# %%
df['Departure Delay in Minutes']
# Out:
# 0        25
# 1         1
# 2         0
# 3        11
# 4         0
#          ..
# 25971     0
# 25972     0
# 25973     0
# 25974     0
# 25975     0
# Name: Departure Delay in Minutes, Length: 129880, dtype: int64

# %%
num=df.select_dtypes(include='number')

# %%
num.columns

# %%
[ i.replace(' ','_') for i in df.columns]
# Out:
# ['Gender',
#  'Customer_Type',
#  'Age',
#  'Type_of_Travel',
#  'Class',
#  'Flight_Distance',
#  'Inflight_wifi_service',
#  'Departure/Arrival_time_convenient',
#  'Ease_of_Online_booking',
#  'Gate_location',
#  'Food_and_drink',
#  'Online_boarding',
#  'Seat_comfort',
#  'Inflight_entertainment',
#  'On-board_service',
#  'Leg_room_service',
#  'Baggage_handling',
#  'Checkin_service',
#  'Inflight_service',
#  'Cleanliness',
#  'Departure_Delay_in_Minutes',
#  'Arrival_Delay_in_Minutes',
#  'satisfaction']

# %%
df['satisfaction'].value_counts(normalize=True)*100
# Out:
# neutral or dissatisfied    56.553742
# satisfied                  43.446258
# Name: satisfaction, dtype: float64

# %%
df['satisfaction']=df['satisfaction'].replace({'neutral or dissatisfied':0,'satisfied':1})

# %%
df['satisfaction'].value_counts(normalize=True)*100
# Out:
# 0    56.553742
# 1    43.446258
# Name: satisfaction, dtype: float64

# %%
df['satisfaction'].value_counts(normalize=True).plot(kind='bar',color=['darkorange','steelblue'],alpha=0.9,rot=0)
plt.show()

# %%
for i in num:
  sns.distplot(df[i])
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df.corr()
# Out:
#                                         Age  ...  satisfaction
# Age                                1.000000  ...      0.134091
# Flight Distance                    0.099459  ...      0.298085
# Inflight wifi service              0.016116  ...      0.283460
# Departure/Arrival time convenient  0.036960  ...     -0.054270
# Ease of Online booking             0.022565  ...      0.168877
# Gate location                     -0.000398  ...     -0.002793
# Food and drink                     0.023194  ...      0.211340
# Online boarding                    0.207572  ...      0.501749
# Seat comfort                       0.159136  ...      0.348829
# Inflight entertainment             0.074947  ...      0.398234
# On-board service                   0.057078  ...      0.322205
# Leg room service                   0.039119  ...      0.312424
# Baggage handling                  -0.047991  ...      0.248680
# Checkin service                    0.033475  ...      0.237252
# ...

# %%
plt.rcParams['figure.figsize']=(15,8)
sns.heatmap(df.corr(),annot=True)

# %%
dc=df.corr()
dc[((dc>0.05) | (dc<-0.05)).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Age, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: []

# %%
fig = plt.figure(figsize = (8,5))
df.satisfaction.value_counts(normalize = True).plot(kind='bar', color= ['darkorange','steelblue'], alpha = 0.9, rot=0)

# %%
df
# Out:
#        Gender      Customer Type  ...  Arrival Delay in Minutes satisfaction
# 0        Male     Loyal Customer  ...                      18.0            0
# 1        Male  disloyal Customer  ...                       6.0            0
# 2      Female     Loyal Customer  ...                       0.0            1
# 3      Female     Loyal Customer  ...                       9.0            0
# 4        Male     Loyal Customer  ...                       0.0            1
# ...       ...                ...  ...                       ...          ...
# 25971    Male  disloyal Customer  ...                       0.0            0
# 25972    Male     Loyal Customer  ...                       0.0            1
# 25973  Female     Loyal Customer  ...                       0.0            0
# 25974    Male     Loyal Customer  ...                       0.0            1
# 25975  Female     Loyal Customer  ...                       0.0            0
#
# [129880 rows x 23 columns]

# %%
sns.countplot(df['Gender'])
plt.show()
plt.savefig('Gender.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Age'].plot(kind='pie')

# %%
cc=df.select_dtypes(include='object').columns

# %%
plt.rcParams['figure.figsize']=(11,5)
for i in cc:
  sns.countplot(df[i])
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
nn=df.select_dtypes(include='number').columns

# %%
for i in nn:
  sns.boxplot(df['satisfaction'],df[i])
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
df['Food and drink']
# Out:
# 0        5
# 1        1
# 2        5
# 3        2
# 4        4
#         ..
# 25971    4
# 25972    4
# 25973    2
# 25974    4
# 25975    4
# Name: Food and drink, Length: 129880, dtype: int64

# %%
df.skew()
# Out:
# Age                                 -0.003606
# Flight Distance                      1.108142
# Inflight wifi service                0.040465
# Departure/Arrival time convenient   -0.332469
# Ease of Online booking              -0.018779
# Gate location                       -0.058265
# Food and drink                      -0.155063
# Online boarding                     -0.456911
# Seat comfort                        -0.485818
# Inflight entertainment              -0.366385
# On-board service                    -0.421320
# Leg room service                    -0.348414
# Baggage handling                    -0.677400
# Checkin service                     -0.366569
# Inflight service                    -0.691580
# Cleanliness                         -0.300926
# Departure Delay in Minutes           6.821980
# Arrival Delay in Minutes             6.670125
# satisfaction                         0.264434
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
nn=df[['Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
       'satisfaction']]

# %%
pt=PowerTransformer()

# %%
df1=pd.DataFrame(pt.fit_transform(nn),columns=['Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
       'satisfaction'])

# %%
df1.skew()
# Out:
# Flight Distance                     -0.027146
# Inflight wifi service               -0.087151
# Departure/Arrival time convenient   -0.234685
# Ease of Online booking              -0.111587
# Gate location                       -0.115002
# Food and drink                      -0.144529
# Online boarding                     -0.211768
# Seat comfort                        -0.243220
# Inflight entertainment              -0.212150
# On-board service                    -0.204042
# Leg room service                    -0.193251
# Baggage handling                    -0.228044
# Checkin service                     -0.172426
# Inflight service                    -0.230683
# Cleanliness                         -0.178569
# Departure Delay in Minutes           0.493976
# Arrival Delay in Minutes             0.468577
# satisfaction                         0.264434
# dtype: float64

# %%
for i in nn.columns:
  sns.distplot(df1[i])
  plt.show()

# %%
sns.distplot(df['Departure Delay in Minutes'])

# %%
sns.distplot(np.sqrt(df['Departure Delay in Minutes']))

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean())

# %%
df2=pd.DataFrame(sc.fit_transform(df),columns=df.columns)

# %%
from sklearn.preprocessing import LabelEncoder
lencoders = {}
for col in df.select_dtypes(include=['object']).columns:
    lencoders[col] = LabelEncoder()
    df[col] = lencoders[col].fit_transform(df[col])

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Gender                                  1.0
# Customer Type                           0.0
# Age                                    24.0
# Type of Travel                          1.0
# Class                                   1.0
# Flight Distance                      1330.0
# Inflight wifi service                   2.0
# Departure/Arrival time convenient       2.0
# Ease of Online booking                  2.0
# Gate location                           2.0
# Food and drink                          2.0
# Online boarding                         2.0
# Seat comfort                            3.0
# Inflight entertainment                  2.0
# On-board service                        2.0
# Leg room service                        2.0
# Baggage handling                        2.0
# Checkin service                         1.0
# Inflight service                        2.0
# Cleanliness                             2.0
# Departure Delay in Minutes             12.0
# ...

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (76442, 23)

# %%
plt.rcParams['figure.figsize']=(15,8)
sns.heatmap(df.corr(),annot=True)

# %%
from sklearn.feature_selection import SelectKBest, chi2
X = df2.loc[:,df2.columns!='satisfaction']
y = df2[['satisfaction']]
selector = SelectKBest(chi2, k=10)
selector.fit(X, y)
X_new = selector.transform(X)
print(X.columns[selector.get_support(indices=True)])
# Out:
# Index(['Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Cleanliness'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             196
# satisfaction                           0
# ...

# %%
from sklearn.over_sampling import SMOTE
smote=SMOTE(random_state=10)

# %%
for i in cc:
  ct=pd.crosstab(df[i],df['Satisfaction'])
  print("p-value for column:",stats.chi2_contigency(ct)[1])

# %%
for i in nn:
  print("p-value for column:",stats.ttest_ind(df[df['satisfaction']==1][i],df[df['satisfaction']==0][i])
